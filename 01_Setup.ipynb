# %% [markdown]
# ### # Install the required libraries

# %%
# %pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (3.10.9)
# Requirement already satisfied: seaborn in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (1.7.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\dinesh singh dhami\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### # Test everything

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import sqlite3

print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
print("Seaborn version:", sns.__version__)
print("Scikit-learn version:", sklearn.__version__)

print("\n✅ PROJECT SETUP SUCCESSFUL!")
# Out:
# Pandas version: 2.3.3
# NumPy version: 1.26.4
# Seaborn version: 0.13.2
# Scikit-learn version: 1.7.2
#
# ✅ PROJECT SETUP SUCCESSFUL!

# %%
import os

print("Files in my project folder:")
print(os.listdir())
# Out:
# Files in my project folder:
# ['.ipynb_checkpoints', '01_Setup.ipynb', 'train.csv']
